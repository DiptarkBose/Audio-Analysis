# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
clinical_info_file_path = "clinical_info.xlsx"
df = pd.read_excel(clinical_info_file_path, engine="openpyxl")

# %%
def visualize_patient_BDI_PSS(patient_id):

    df_patient = df.loc[df['SID'] == patient_id]
    df_BDI = df_patient[['BDItotalscore_ED', 'BDItotalscore_1mo', 'BDItotalscore_3mo', 'BDItotalscore_6mo', 'BDItotalscore_12mo']]
    df_PSS = df_patient[['PSStotal_1month', 'PSStotal_1month', 'PSStotal_3month', 'PSStotal_6month', 'PSStotal_12month']]
    x_axis = ["ED", "FU-1", "FU-3", "FU-6", "FU-12"]
    df_BDI = df_BDI.values.tolist()[0]
    df_PSS = df_PSS.values.tolist()[0]
    plt.plot(x_axis, df_BDI, label="BDI Scores for Patient "+str(patient_id))
    plt.plot(x_axis, df_PSS, label="PSS Scores for Patient "+str(patient_id))
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('BDI & PSS Scores')
    plt.title("BDI & PSS Scores for Patient "+str(patient_id))
    plt.show()

# %%
df_all_patient_ids = df[['SID']].values.tolist()
for patient in df_all_patient_ids:
    visualize_patient_BDI_PSS(patient[0])

# %% [markdown]
# ## Observation:
# 1. BDI and PSS patterns almost match for patient 50129, whereas its a total mismatch for patient 50080 and 50109.
# 2. However, this observation doesn't make a lot of sense to me. Wouldn't a person suffering from high PTSD be naturally depressed? Ask Dr. Arriaga about this.

# %% [markdown]
# ## Takeaways:
# 1. BDI and PSS are NOT correlated to each other. In some cases, as we saw, they can have wildly different trajectories. Therefore, while doing audio analysis, I should probably try to correlate my results with the PSS scores too, and not just focus on BDI.
# 2. Heard a few followups as well. Audio relatively cleaner. Should be easier to analyze. Need to identify segments of most importance.
