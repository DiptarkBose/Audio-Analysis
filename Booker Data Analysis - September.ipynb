# %% [markdown]
# # Booker Data Analysis
#
# Now that we have the Booker data with us, I would be analyzing the audio files. The audio files aren't very clear due to a lot of noise, so I preprocess it by manually removing noises using Adobe Audition.
#
# Here's a list of extracted features:
#
# 1. MFCC
# 2. Zero Crossings
# 3. Spectral Centroid
# 4. Spectrogram
# 5. Chroma FFT
# 6. Energy
# 7. RMS Energy
# 8. Spectral Rolloff
# 9. Phonation Rate
# 10. Speech Productivity
# 11. Speech Rate
# 12. Articulation Rate

# %%
import librosa 
import librosa.display
from scipy.io import wavfile as wav
import speech_recognition as sr
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
import sklearn
from pydub import AudioSegment 
from pydub.silence import split_on_silence 
import ffmpeg
from sklearn.svm import SVC
# Out:
# C:\Users\diptarkbose\Anaconda3\envs\deep_learning_setup\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
def compute_all_features(audio, path, sample_rate):
    
    # Compute Zero Crossings. And compute ZC mean and variance.
    audio_zc = librosa.zero_crossings(audio, pad=False)
    print("\nZero Crossings Mean:"+str(np.mean(audio_zc)))
    print("Zero Crossings Variance:"+str(np.var(audio_zc, dtype = np.float32)))
        
        
    # Compute Spectral Centroid. And compute SC mean and variance.
    spectral_centroids = librosa.feature.spectral_centroid(audio, sr=sample_rate)[0]
    print("\nSpectral Centroid Mean:"+str(np.mean(spectral_centroids)))
    print("Spectral Centroid Variance:"+str(np.var(spectral_centroids, dtype = np.float32)))
    
    
    # Compute RMS Energy. And compute RMS Energy mean and variance.
    rmse = librosa.feature.rms(audio, frame_length=512, hop_length=256, center=True)
    rmse = rmse[0]
    print("\nRMS Energy Mean:"+str(np.mean(rmse)))
    print("RMS Energy Variance:"+str(np.var(rmse, dtype = np.float32)))
    
    
    # Compute Spectral Rolloff. And compute Spectral Rolloff mean and variance.
    spectral_rolloff = librosa.feature.spectral_rolloff(audio+0.01, sr=sample_rate)[0]
    print("\nSpectral Rolloff Mean:"+str(np.mean(spectral_rolloff)))
    print("Spectral Rolloff Variance:"+str(np.var(spectral_rolloff, dtype = np.float32)))
    
    
    # Compute all prosodic features.
    prosodic_features = {
        "phonation_rate" : 0,
        "speech_productivity" : 0,
        "speech_rate" : 0,
        "articulation_rate" : 0
    }
    audio_duration = librosa.get_duration(filename=path)
    audio_for_prosody, sample_rate = librosa.load(path, duration=audio_duration) 
    voiced_intervals = librosa.effects.split(y=audio_for_prosody, top_db=20)
    total_voiced_duration = 0
    for interval in voiced_intervals:
        total_voiced_duration = total_voiced_duration + ((interval[1]-interval[0])/sample_rate)
    if total_voiced_duration > audio_duration:
        total_voiced_duration = audio_duration
    total_silenced_duration = audio_duration-total_voiced_duration
    prosodic_features["phonation_rate"] = total_voiced_duration/audio_duration
    prosodic_features["speech_productivity"] = (total_silenced_duration)/total_voiced_duration
    # Will calculate speech_rate and articulation rate from transcripts. This is for better accuracy.    
    print("\nProsodic Features: " + str(prosodic_features))
    
    
    # Compute MFCCs. And compute MFCC means and variances.
    audio_mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=14)
    print("\nMFCC Means:")
    for i in range(1, 14):
        print("MFCC Mean for Coefficient-"+ str(i) +": "+str(np.mean(audio_mfcc[i])))
    print("\nMFCC Variances:")
    for i in range(1, 14):
        print("MFCC Variance for Coefficient-"+ str(i) +": "+str(np.var(audio_mfcc[i], dtype = np.float32)))
    
    
    # Compute Chroma 12 Pitch Scale. And compute Chroma 12 Pitch Scale means and variances.
    chromagram = librosa.feature.chroma_stft(audio, sr=sample_rate, hop_length=512)
    print("\nChromagram Means:")
    for i in range(0, 12):
        print("Chromagram Mean for Coefficient-"+ str(i) +": "+str(np.mean(chromagram[i])))
    print("\nChromagram Variances:")
    for i in range(0, 12):
        print("Chromagram Variance for Coefficient-"+ str(i) +": "+str(np.var(chromagram[i], dtype = np.float32)))
    
    
    
    
    
    '''
    # Visualize Spectrogram
    audio_spectrogram = librosa.stft(audio)
    audio_spectrogram_db = librosa.amplitude_to_db(abs(audio_spectrogram))
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(audio_spectrogram_db, sr=sample_rate, x_axis='time', y_axis='hz')
    plt.colorbar()
    '''

# %%
# Patient 50064
filename1 = 'booker_audio_files/50064/50064.wav'
audio, sample_rate = librosa.load(filename1) 
compute_all_features(audio, filename1, sample_rate)
# Out:
# Zero Crossings Mean:0.031361363630157374
# Zero Crossings Variance:0.030377826
#
# Spectral Centroid Mean:901.9457383994927
# Spectral Centroid Variance:146120.34
#
# RMS Energy Mean:0.100771286
# RMS Energy Variance:0.004343562
#
# Spectral Rolloff Mean:1747.7632726513364
# Spectral Rolloff Variance:743616.06
#
# Prosodic Features: {'phonation_rate': 0.995806239098304, 'speech_productivity': 0.004211422601141212, 'speech_rate': 0, 'articulation_rate': 0}
#
# MFCC Means:
# MFCC Mean for Coefficient-1: 165.15202
# MFCC Mean for Coefficient-2: -6.6579204
# MFCC Mean for Coefficient-3: 36.626087
# MFCC Mean for Coefficient-4: 13.852268
# MFCC Mean for Coefficient-5: 12.565309
# MFCC Mean for Coefficient-6: 3.2800207
# MFCC Mean for Coefficient-7: -1.4506346
# MFCC Mean for Coefficient-8: 3.6713154
# MFCC Mean for Coefficient-9: 6.163911
# MFCC Mean for Coefficient-10: -2.0189536
# MFCC Mean for Coefficient-11: 3.071324
# MFCC Mean for Coefficient-12: 5.2797112
# MFCC Mean for Coefficient-13: -2.8786998
#
# MFCC Variances:
# MFCC Variance for Coefficient-1: 1497.9633
# MFCC Variance for Coefficient-2: 417.73935
# MFCC Variance for Coefficient-3: 437.5155
# MFCC Variance for Coefficient-4: 292.41644
# MFCC Variance for Coefficient-5: 179.05162
# MFCC Variance for Coefficient-6: 295.52176
# MFCC Variance for Coefficient-7: 260.5452
# MFCC Variance for Coefficient-8: 120.75519
# MFCC Variance for Coefficient-9: 86.89963
# MFCC Variance for Coefficient-10: 144.01295
# MFCC Variance for Coefficient-11: 69.328766
# MFCC Variance for Coefficient-12: 87.07641
# MFCC Variance for Coefficient-13: 58.588535
#
# Chromagram Means:
# Chromagram Mean for Coefficient-0: 0.49760333
# Chromagram Mean for Coefficient-1: 0.431232
# Chromagram Mean for Coefficient-2: 0.4503794
# Chromagram Mean for Coefficient-3: 0.4602764
# Chromagram Mean for Coefficient-4: 0.40301424
# Chromagram Mean for Coefficient-5: 0.44102153
# Chromagram Mean for Coefficient-6: 0.5819127
# Chromagram Mean for Coefficient-7: 0.61731035
# Chromagram Mean for Coefficient-8: 0.5202645
# Chromagram Mean for Coefficient-9: 0.47005847
# Chromagram Mean for Coefficient-10: 0.5218852
# Chromagram Mean for Coefficient-11: 0.530615
#
# Chromagram Variances:
# Chromagram Variance for Coefficient-0: 0.12098392
# Chromagram Variance for Coefficient-1: 0.09514078
# Chromagram Variance for Coefficient-2: 0.08861392
# Chromagram Variance for Coefficient-3: 0.09026831
# Chromagram Variance for Coefficient-4: 0.0851792
# Chromagram Variance for Coefficient-5: 0.08120691
# Chromagram Variance for Coefficient-6: 0.08552788
# Chromagram Variance for Coefficient-7: 0.07659291
# Chromagram Variance for Coefficient-8: 0.07859572
# Chromagram Variance for Coefficient-9: 0.08297418
# Chromagram Variance for Coefficient-10: 0.10627886
# Chromagram Variance for Coefficient-11: 0.11953708

# %%
# Patient 50063
filename1 = 'booker_audio_files/50063/50063.wav'
audio, sample_rate = librosa.load(filename1) 
compute_all_features(audio, filename1, sample_rate)
# Out:
# Zero Crossings Mean:0.03178537901900962
# Zero Crossings Variance:0.030775068
#
# Spectral Centroid Mean:889.0570388347704
# Spectral Centroid Variance:319750.12
#
# RMS Energy Mean:0.079679936
# RMS Energy Variance:0.003519452
#
# Spectral Rolloff Mean:1539.4018234052533
# Spectral Rolloff Variance:2094844.1
#
# Prosodic Features: {'phonation_rate': 0.9847462676989224, 'speech_productivity': 0.0154900128098189, 'speech_rate': 0, 'articulation_rate': 0}
#
# MFCC Means:
# MFCC Mean for Coefficient-1: 161.23753
# MFCC Mean for Coefficient-2: 28.973692
# MFCC Mean for Coefficient-3: 32.278355
# MFCC Mean for Coefficient-4: 7.9164352
# MFCC Mean for Coefficient-5: 12.3973675
# MFCC Mean for Coefficient-6: -6.5472717
# MFCC Mean for Coefficient-7: -2.1759808
# MFCC Mean for Coefficient-8: 4.1985564
# MFCC Mean for Coefficient-9: 8.523919
# MFCC Mean for Coefficient-10: -0.46817333
# MFCC Mean for Coefficient-11: 9.002686
# MFCC Mean for Coefficient-12: -4.390409
# MFCC Mean for Coefficient-13: -2.3235826
#
# MFCC Variances:
# MFCC Variance for Coefficient-1: 980.68225
# MFCC Variance for Coefficient-2: 486.3424
# MFCC Variance for Coefficient-3: 216.06842
# MFCC Variance for Coefficient-4: 274.07416
# MFCC Variance for Coefficient-5: 180.38193
# MFCC Variance for Coefficient-6: 281.41595
# MFCC Variance for Coefficient-7: 157.23053
# MFCC Variance for Coefficient-8: 94.39617
# MFCC Variance for Coefficient-9: 82.99371
# MFCC Variance for Coefficient-10: 99.682495
# MFCC Variance for Coefficient-11: 95.393776
# MFCC Variance for Coefficient-12: 113.362114
# MFCC Variance for Coefficient-13: 101.69022
#
# Chromagram Means:
# Chromagram Mean for Coefficient-0: 0.48632085
# Chromagram Mean for Coefficient-1: 0.42369622
# Chromagram Mean for Coefficient-2: 0.48898378
# Chromagram Mean for Coefficient-3: 0.5502866
# Chromagram Mean for Coefficient-4: 0.53654987
# Chromagram Mean for Coefficient-5: 0.48878595
# Chromagram Mean for Coefficient-6: 0.4745098
# Chromagram Mean for Coefficient-7: 0.3895948
# Chromagram Mean for Coefficient-8: 0.36492172
# Chromagram Mean for Coefficient-9: 0.40835425
# Chromagram Mean for Coefficient-10: 0.43937704
# Chromagram Mean for Coefficient-11: 0.51188225
#
# Chromagram Variances:
# Chromagram Variance for Coefficient-0: 0.10835299
# Chromagram Variance for Coefficient-1: 0.073699474
# Chromagram Variance for Coefficient-2: 0.08468367
# Chromagram Variance for Coefficient-3: 0.09501492
# Chromagram Variance for Coefficient-4: 0.09584721
# Chromagram Variance for Coefficient-5: 0.08970067
# Chromagram Variance for Coefficient-6: 0.08999207
# Chromagram Variance for Coefficient-7: 0.0784001
# Chromagram Variance for Coefficient-8: 0.072418824
# Chromagram Variance for Coefficient-9: 0.07540402
# Chromagram Variance for Coefficient-10: 0.082779676
# Chromagram Variance for Coefficient-11: 0.12678207

# %%
# Patient 50059
filename1 = 'booker_audio_files/50059/50059.wav'
audio, sample_rate = librosa.load(filename1) 
compute_all_features(audio, filename1, sample_rate)
# Out:
# Zero Crossings Mean:0.0324321372545126
# Zero Crossings Variance:0.031380307
#
# Spectral Centroid Mean:926.156540875741
# Spectral Centroid Variance:187086.78
#
# RMS Energy Mean:0.08039084
# RMS Energy Variance:0.0034302706
#
# Spectral Rolloff Mean:1721.7142456520012
# Spectral Rolloff Variance:1356889.0
#
# Prosodic Features: {'phonation_rate': 0.872364990794665, 'speech_productivity': 0.14630918314256072, 'speech_rate': 0, 'articulation_rate': 0}
#
# MFCC Means:
# MFCC Mean for Coefficient-1: 161.37962
# MFCC Mean for Coefficient-2: 5.547751
# MFCC Mean for Coefficient-3: 34.576374
# MFCC Mean for Coefficient-4: 7.791508
# MFCC Mean for Coefficient-5: 8.032114
# MFCC Mean for Coefficient-6: 1.1233388
# MFCC Mean for Coefficient-7: 4.3674273
# MFCC Mean for Coefficient-8: 3.8192782
# MFCC Mean for Coefficient-9: -1.4477811
# MFCC Mean for Coefficient-10: 0.333811
# MFCC Mean for Coefficient-11: -1.0468962
# MFCC Mean for Coefficient-12: -0.61345625
# MFCC Mean for Coefficient-13: 3.5625873
#
# MFCC Variances:
# MFCC Variance for Coefficient-1: 1068.8423
# MFCC Variance for Coefficient-2: 715.2396
# MFCC Variance for Coefficient-3: 433.15103
# MFCC Variance for Coefficient-4: 317.702
# MFCC Variance for Coefficient-5: 183.48225
# MFCC Variance for Coefficient-6: 180.44858
# MFCC Variance for Coefficient-7: 122.43471
# MFCC Variance for Coefficient-8: 98.19854
# MFCC Variance for Coefficient-9: 79.29607
# MFCC Variance for Coefficient-10: 76.25466
# MFCC Variance for Coefficient-11: 60.140236
# MFCC Variance for Coefficient-12: 57.337196
# MFCC Variance for Coefficient-13: 44.352337
#
# Chromagram Means:
# Chromagram Mean for Coefficient-0: 0.6485904
# Chromagram Mean for Coefficient-1: 0.5999172
# Chromagram Mean for Coefficient-2: 0.48488286
# Chromagram Mean for Coefficient-3: 0.37985852
# Chromagram Mean for Coefficient-4: 0.2921905
# Chromagram Mean for Coefficient-5: 0.29392254
# Chromagram Mean for Coefficient-6: 0.25119513
# Chromagram Mean for Coefficient-7: 0.27272
# Chromagram Mean for Coefficient-8: 0.3149609
# Chromagram Mean for Coefficient-9: 0.39397556
# Chromagram Mean for Coefficient-10: 0.42685664
# Chromagram Mean for Coefficient-11: 0.52237135
#
# Chromagram Variances:
# Chromagram Variance for Coefficient-0: 0.11999044
# Chromagram Variance for Coefficient-1: 0.09275097
# Chromagram Variance for Coefficient-2: 0.09078538
# Chromagram Variance for Coefficient-3: 0.09548462
# Chromagram Variance for Coefficient-4: 0.07144922
# Chromagram Variance for Coefficient-5: 0.08437791
# Chromagram Variance for Coefficient-6: 0.049489375
# Chromagram Variance for Coefficient-7: 0.0557822
# Chromagram Variance for Coefficient-8: 0.060684096
# Chromagram Variance for Coefficient-9: 0.08783855
# Chromagram Variance for Coefficient-10: 0.101563096
# Chromagram Variance for Coefficient-11: 0.112219

# %%
# Patient 50057
filename1 = 'booker_audio_files/50057/50057.wav'
audio, sample_rate = librosa.load(filename1) 
compute_all_features(audio, filename1, sample_rate)
# Out:
# Zero Crossings Mean:0.04743126503983004
# Zero Crossings Variance:0.045181543
#
# Spectral Centroid Mean:1063.8904747599042
# Spectral Centroid Variance:403329.5
#
# RMS Energy Mean:0.117535636
# RMS Energy Variance:0.0048512933
#
# Spectral Rolloff Mean:1811.2967266613923
# Spectral Rolloff Variance:2038095.1
#
# Prosodic Features: {'phonation_rate': 1.0, 'speech_productivity': 0.0, 'speech_rate': 0, 'articulation_rate': 0}
#
# MFCC Means:
# MFCC Mean for Coefficient-1: 175.40233
# MFCC Mean for Coefficient-2: 13.735252
# MFCC Mean for Coefficient-3: 13.81646
# MFCC Mean for Coefficient-4: -18.284494
# MFCC Mean for Coefficient-5: 19.938261
# MFCC Mean for Coefficient-6: -4.943243
# MFCC Mean for Coefficient-7: -8.8996
# MFCC Mean for Coefficient-8: 5.963514
# MFCC Mean for Coefficient-9: 12.946238
# MFCC Mean for Coefficient-10: 1.5585879
# MFCC Mean for Coefficient-11: 6.4151607
# MFCC Mean for Coefficient-12: 1.195284
# MFCC Mean for Coefficient-13: 0.41297102
#
# MFCC Variances:
# MFCC Variance for Coefficient-1: 1407.8855
# MFCC Variance for Coefficient-2: 377.77145
# MFCC Variance for Coefficient-3: 459.97983
# MFCC Variance for Coefficient-4: 394.2882
# MFCC Variance for Coefficient-5: 306.8548
# MFCC Variance for Coefficient-6: 162.21332
# MFCC Variance for Coefficient-7: 256.20737
# MFCC Variance for Coefficient-8: 92.497665
# MFCC Variance for Coefficient-9: 111.42499
# MFCC Variance for Coefficient-10: 104.56731
# MFCC Variance for Coefficient-11: 75.812195
# MFCC Variance for Coefficient-12: 75.52775
# MFCC Variance for Coefficient-13: 85.32869
#
# Chromagram Means:
# Chromagram Mean for Coefficient-0: 0.42834032
# Chromagram Mean for Coefficient-1: 0.34739667
# Chromagram Mean for Coefficient-2: 0.33153567
# Chromagram Mean for Coefficient-3: 0.28975427
# Chromagram Mean for Coefficient-4: 0.2653816
# Chromagram Mean for Coefficient-5: 0.33443
# Chromagram Mean for Coefficient-6: 0.40002704
# Chromagram Mean for Coefficient-7: 0.3820025
# Chromagram Mean for Coefficient-8: 0.40045455
# Chromagram Mean for Coefficient-9: 0.41380158
# Chromagram Mean for Coefficient-10: 0.51380754
# Chromagram Mean for Coefficient-11: 0.5503919
#
# Chromagram Variances:
# Chromagram Variance for Coefficient-0: 0.08960893
# Chromagram Variance for Coefficient-1: 0.06781077
# Chromagram Variance for Coefficient-2: 0.06961357
# Chromagram Variance for Coefficient-3: 0.061873596
# Chromagram Variance for Coefficient-4: 0.056845672
# Chromagram Variance for Coefficient-5: 0.075465366
# Chromagram Variance for Coefficient-6: 0.08308969
# Chromagram Variance for Coefficient-7: 0.07341115
# Chromagram Variance for Coefficient-8: 0.07748117
# Chromagram Variance for Coefficient-9: 0.07114355
# Chromagram Variance for Coefficient-10: 0.108971305
# Chromagram Variance for Coefficient-11: 0.14360116

# %%
# Patient 50051
# This patient had:
# BDI Score = 4 at ED
# BDI Score = 2 after treatment
filename1 = 'booker_audio_files/50051/50051.wav'
audio, sample_rate = librosa.load(filename1) 
compute_all_features(audio, filename1, sample_rate)
# Out:
# Zero Crossings Mean:0.06425597818187143
# Zero Crossings Variance:0.060127147
#
# Spectral Centroid Mean:1495.3839485235508
# Spectral Centroid Variance:144252.83
#
# RMS Energy Mean:0.046276104
# RMS Energy Variance:0.0007027266
#
# Spectral Rolloff Mean:3023.1095569292024
# Spectral Rolloff Variance:906166.25
#
# Prosodic Features: {'phonation_rate': 0.8182268796750707, 'speech_productivity': 0.2221549118468388, 'speech_rate': 0, 'articulation_rate': 0}
#
# MFCC Means:
# MFCC Mean for Coefficient-1: 127.85316
# MFCC Mean for Coefficient-2: -14.550718
# MFCC Mean for Coefficient-3: 39.20887
# MFCC Mean for Coefficient-4: 6.597484
# MFCC Mean for Coefficient-5: 17.933455
# MFCC Mean for Coefficient-6: -3.440447
# MFCC Mean for Coefficient-7: -4.4502873
# MFCC Mean for Coefficient-8: -4.0730553
# MFCC Mean for Coefficient-9: 9.211929
# MFCC Mean for Coefficient-10: 4.4426985
# MFCC Mean for Coefficient-11: 11.246981
# MFCC Mean for Coefficient-12: 3.4335325
# MFCC Mean for Coefficient-13: 4.5402703
#
# MFCC Variances:
# MFCC Variance for Coefficient-1: 534.23425
# MFCC Variance for Coefficient-2: 379.22116
# MFCC Variance for Coefficient-3: 225.22835
# MFCC Variance for Coefficient-4: 133.26035
# MFCC Variance for Coefficient-5: 192.95221
# MFCC Variance for Coefficient-6: 179.78258
# MFCC Variance for Coefficient-7: 153.65274
# MFCC Variance for Coefficient-8: 131.1935
# MFCC Variance for Coefficient-9: 78.86461
# MFCC Variance for Coefficient-10: 75.03583
# MFCC Variance for Coefficient-11: 67.087524
# MFCC Variance for Coefficient-12: 67.59042
# MFCC Variance for Coefficient-13: 55.25669
#
# Chromagram Means:
# Chromagram Mean for Coefficient-0: 0.35709456
# Chromagram Mean for Coefficient-1: 0.31832245
# Chromagram Mean for Coefficient-2: 0.3206946
# Chromagram Mean for Coefficient-3: 0.3699143
# Chromagram Mean for Coefficient-4: 0.33140084
# Chromagram Mean for Coefficient-5: 0.28723294
# Chromagram Mean for Coefficient-6: 0.3179398
# Chromagram Mean for Coefficient-7: 0.43138888
# Chromagram Mean for Coefficient-8: 0.43565783
# Chromagram Mean for Coefficient-9: 0.4232806
# Chromagram Mean for Coefficient-10: 0.46905968
# Chromagram Mean for Coefficient-11: 0.45216608
#
# Chromagram Variances:
# Chromagram Variance for Coefficient-0: 0.10195859
# Chromagram Variance for Coefficient-1: 0.078916594
# Chromagram Variance for Coefficient-2: 0.0745599
# Chromagram Variance for Coefficient-3: 0.09513114
# Chromagram Variance for Coefficient-4: 0.08227921
# Chromagram Variance for Coefficient-5: 0.06929151
# Chromagram Variance for Coefficient-6: 0.07412138
# Chromagram Variance for Coefficient-7: 0.1003125
# Chromagram Variance for Coefficient-8: 0.094810516
# Chromagram Variance for Coefficient-9: 0.08755349
# Chromagram Variance for Coefficient-10: 0.11315407
# Chromagram Variance for Coefficient-11: 0.1287368

# %% [markdown]
# ## Observations
#
# 1. The numbers aren't conclusively pointing towards any traits.
# 2. There are just too many variables that seem to create bias. I felt that the gender had a role to play in spectral centroids calculation. There are instances where speaker is closer to the mic, which is shooting their RMS Energy a bit higher than the rest.
# 3. After taking a look at the outputs, I felt that phonation and speech rate only were helpful.
# 4. Just comparing ED sessions of different patients LACKS context. We need to change our approach, and try comparing ED and FU sessions.
# 5. Another thing that I noticed was, there is no point to compare just ED and last FU session. Take patient 50051 for example. This patient had BDI values of 4 -> 6 ->7 -> 5 -> 2. So values first increase and then decrease. This proves that we can't expect a steady increase or decrease.
